# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

sin_theta = np.array([-0.0446, -0.02998, -0.015, 0.04611, 0.02998, 0.015])


#yl=np.array([-.09/6, -.18/6, -26.8/6, .09/6, .18/6, .277/6])
#theta= np.arctan(np.radians (yl)) 
#sintheta = np.sin(theta)

#xvariable_sintheta = np.sin(np.radians(np.arctan(np.array([-.09/6, -.18/6, -26.8/6, .09/6, .18/6, .277/6]))))
#print (xvariable_sintheta)
#print (yl)
#print (theta)
#print (sintheta)

yvariable_p = np.array([-3, -2, -1, 3, 2, 1]) 

err_yvariable_p = np.array([.25, .25, .25, .25, .25, .25])

x = sin_theta   
y = yvariable_p
dy = err_yvariable_p  

b,m=np.polynomial.polynomial.polyfit(x,y,1,w=dy)

fit = b+m*x

def Delta(x, dy):
    D = (sum(1/dy**2))*(sum(x**2/dy**2))-(sum(x/dy**2))**2
    return D
 
D=Delta(x, dy)
 
dm = np.sqrt(1/D*sum(1/dy**2)) 
db = np.sqrt(1/D*sum(x**2/dy**2)) 

def LLSFD2(x,y,dy):
    N = sum(((y-b-m*x)/dy)**2)
    return N
                      
N = LLSFD2(x,y,dy)

plt.figure(figsize=(15,10))
 
plt.plot(x, fit, color='mediumaquamarine', linestyle='--')
plt.scatter(x, y, color='blue', marker='o')
 
plt.xlabel('sin (theta)')
plt.ylabel('p')
plt.title('Slope for Diffraction')
 
plt.errorbar(x, y, yerr=dy, xerr=None, fmt="none") 
 
plt.annotate('Slope = {value:.{digits}E}'.format(value=m, digits=2),
             (0.05, 0.9), xycoords='axes fraction')
 
plt.annotate('Error in Slope = {value:.{digits}E}'.format(value=dm, digits=1),
             (0.05, 0.85), xycoords='axes fraction')
 
plt.annotate('Goodness of fit = {value:.{digits}E}'.format(value=N, digits=2),
             (0.05, 0.80), xycoords='axes fraction')

plt.show()

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

sin_theta = np.array([-0.0295, -0.0245, -0.01499, -0.0098, -0.00499, 0.0388, 0.0350, 0.02865, 0.0243, 0.01966, 0.01449, 0.0095, 0.0046])
#xvariable_sintheta = np.sin(np.arctan(np.radians(np.array([-.177/6, -.147/6, -.09/6, -.059/6, -.03/6, .028/6, .057/6, .087/6, .118/6, .146/6, .172/6, .210/6, .233/6])))) 
yvariable_m = np.array([-5, -4, -3, -2, -1, 8, 7, 6, 5, 4, 3, 2, 1]) 



err_yvariable_m = np.array([.25, .25, .25, .25, .25, .25, .25, .25, .25, .25, .25, .25, .25, ])

x = sin_theta   
y = yvariable_m
dy = err_yvariable_m  

b,m=np.polynomial.polynomial.polyfit(x,y,1,w=dy)

fit = b+m*x

def Delta(x, dy):
    D = (sum(1/dy**2))*(sum(x**2/dy**2))-(sum(x/dy**2))**2
    return D
 
D=Delta(x, dy)
 
dm = np.sqrt(1/D*sum(1/dy**2)) 
db = np.sqrt(1/D*sum(x**2/dy**2)) 

def LLSFD2(x,y,dy):
    N = sum(((y-b-m*x)/dy)**2)
    return N
                      
N = LLSFD2(x,y,dy)

plt.figure(figsize=(15,10))
 
plt.plot(x, fit, color='mediumaquamarine', linestyle='--')
plt.scatter(x, y, color='blue', marker='o')
 
plt.xlabel('sin (theta)')
plt.ylabel('m')
plt.title('Slope for Interferance')
 
plt.errorbar(x, y, yerr=dy, xerr=None, fmt="none") 
 
plt.annotate('Slope = {value:.{digits}E}'.format(value=m, digits=2),
             (0.05, 0.9), xycoords='axes fraction')
 
plt.annotate('Error in Slope = {value:.{digits}E}'.format(value=dm, digits=1),
             (0.05, 0.85), xycoords='axes fraction')
 
plt.annotate('Goodness of fit = {value:.{digits}E}'.format(value=N, digits=2),
             (0.05, 0.80), xycoords='axes fraction')

plt.show()
